# %%
import requests
response = requests.get("https://www.geeksforgeeks.org/")
print(response.status_code)
# Out:
# 200

# %%
import requests
response = requests.get("https://api.github.com/users/ahnmkr")
print(response.status_code)
print(response.content)
# Out:
# 200
# b'{"login":"ahnmkr","id":231405158,"node_id":"U_kgDODcr2Zg","avatar_url":"https://avatars.githubusercontent.com/u/231405158?v=4","gravatar_id":"","url":"https://api.github.com/users/ahnmkr","html_url":"https://github.com/ahnmkr","followers_url":"https://api.github.com/users/ahnmkr/followers","following_url":"https://api.github.com/users/ahnmkr/following{/other_user}","gists_url":"https://api.github.com/users/ahnmkr/gists{/gist_id}","starred_url":"https://api.github.com/users/ahnmkr/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ahnmkr/subscriptions","organizations_url":"https://api.github.com/users/ahnmkr/orgs","repos_url":"https://api.github.com/users/ahnmkr/repos","events_url":"https://api.github.com/users/ahnmkr/events{/privacy}","received_events_url":"https://api.github.com/users/ahnmkr/received_events","type":"User","user_view_type":"public","site_admin":false,"name":"Akkala Hema Naga Manikantta Reddy","company":null,"blog":"","location":null,"email":null,"hireable":null,"bio":null,"twitter_username":null,"public_repos":1,"public_gists":0,"followers":0,"following":0,"created_at":"2025-09-10T04:54:12Z","updated_at":"2026-02-10T17:39:42Z"}'

# %%
import requests

# Making a GET request
r = requests.get('https://api.github.com/users/ahnmkr')

# check status code
print(r)

# print content
print(r.content)
# Out:
# <Response [200]>
# b'{"login":"ahnmkr","id":231405158,"node_id":"U_kgDODcr2Zg","avatar_url":"https://avatars.githubusercontent.com/u/231405158?v=4","gravatar_id":"","url":"https://api.github.com/users/ahnmkr","html_url":"https://github.com/ahnmkr","followers_url":"https://api.github.com/users/ahnmkr/followers","following_url":"https://api.github.com/users/ahnmkr/following{/other_user}","gists_url":"https://api.github.com/users/ahnmkr/gists{/gist_id}","starred_url":"https://api.github.com/users/ahnmkr/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ahnmkr/subscriptions","organizations_url":"https://api.github.com/users/ahnmkr/orgs","repos_url":"https://api.github.com/users/ahnmkr/repos","events_url":"https://api.github.com/users/ahnmkr/events{/privacy}","received_events_url":"https://api.github.com/users/ahnmkr/received_events","type":"User","user_view_type":"public","site_admin":false,"name":"Akkala Hema Naga Manikantta Reddy","company":null,"blog":"","location":null,"email":null,"hireable":null,"bio":null,"twitter_username":null,"public_repos":1,"public_gists":0,"followers":0,"following":0,"created_at":"2025-09-10T04:54:12Z","updated_at":"2026-02-10T17:39:42Z"}'

# %%
import requests

# Making a POST request
r = requests.post('https://httpbin.org/post', data={'key':'value'})

# check status code
print(r)

# print content
print(r.json())
# Out:
# <Response [200]>
# {'args': {}, 'data': '', 'files': {}, 'form': {'key': 'value'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '9', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.3', 'X-Amzn-Trace-Id': 'Root=1-698e072a-0929e8d238bfb1736ef92450'}, 'json': None, 'origin': '223.185.119.13', 'url': 'https://httpbin.org/post'}

# %%
import requests

res = requests.put('https://httpbin.org/put', data={'key': 'value'})

print("Status Code:", res.status_code)

print("Response Body:", res.content.decode())
# Out:
# Status Code: 200
# Response Body: {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br, zstd",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-698e0755-49e70de677f75cfe22b85cc7"
#   },
#   "json": null,
#   "origin": "223.185.119.13",
#   "url": "https://httpbin.org/put"
# }

# %%
import requests

# Making a DELETE request
r = requests.delete('https://httpbin.org/delete', data={'key':'value'})

# check status code
print(r)

# print content
print(r.json())
# Out:
# <Response [200]>
# {'args': {}, 'data': '', 'files': {}, 'form': {'key': 'value'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '9', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.3', 'X-Amzn-Trace-Id': 'Root=1-698e079d-1e29ccaf3301d39069b039a9'}, 'json': None, 'origin': '223.185.119.13', 'url': 'https://httpbin.org/delete'}

# %%
import requests

# Making a HEAD request
r = requests.head('https://httpbin.org/', data ={'key':'value'})

# check status code for response received
# success code - 200
print(r)

# print headers of request
print(r.headers)

# checking if request contains any content
print(r.content)
# Out:
# <Response [200]>
# {'Date': 'Thu, 12 Feb 2026 17:02:56 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '9593', 'Connection': 'close', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# b''

# %%
import requests

# Making a PATCH request
r = requests.patch('https://httpbin.org/patch', data={'key':'value'})

# check status code
print(r)

# print content
print(r.content)
# Out:
# <Response [200]>
# b'{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key": "value"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br, zstd", \n    "Content-Length": "9", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.32.3", \n    "X-Amzn-Trace-Id": "Root=1-698e0803-4faa74aa6230ea5e61f82618"\n  }, \n  "json": null, \n  "origin": "223.185.119.13", \n  "url": "https://httpbin.org/patch"\n}\n'

# %%
import requests
response = requests.get('https://api.github.com/')
print(response.url)
print(response.status_code)
# Out:
# https://api.github.com/
# 200

# %%
import requests
payload = {'username': 'test', 'password': 'test123'}
response = requests.post("https://httpbin.org/post", data=payload)
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "password": "test123",
#     "username": "test"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br, zstd",
#     "Content-Length": "30",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-698e0882-2979fc1019ff90e21d74e987"
#   },
#   "json": null,
#   "origin": "223.185.119.13",
#   "url": "https://httpbin.org/post"
# }

# %%
import requests
from requests.auth import HTTPBasicAuth
response = requests.get('https://api.github.com/user', auth=HTTPBasicAuth('user', 'pass'))
print(response.status_code)
# Out:
# 401

# %%
import requests
response = requests.get('https://expired.badssl.com/', verify=False)
print(response.status_code)
# Out:
# C:\Users\manik\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'expired.badssl.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200

# %%
import requests

# Create a session object
session = requests.Session()

# Set a cookie
session.get('https://httpbin.org/cookies')

# Access the cookie in the next request
response = session.get('https://httpbin.org/cookies')
print(response.text)
# Out:
# {
#   "cookies": {}
# }

# %%
import requests

try:
    response = requests.get("https://www.example.com/", timeout=5)
    response.raise_for_status()
except requests.exceptions.HTTPError as errh:
    print("HTTP Error:", errh)
except requests.exceptions.ConnectionError as errc:
    print("Connection Error:", errc)
except requests.exceptions.Timeout as errt:
    print("Timeout Error:", errt)
except requests.exceptions.RequestException as err:
    print("Something Else:", err)
